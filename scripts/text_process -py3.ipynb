# %%
import math
import re
import operator
import csv
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import CountVectorizer

work_dir = 'd:/document/project/phone_csf'
os.chdir(work_dir)

# %% [markdown]
# ### text feature extraction example

# %%
ex_vectorizer = CountVectorizer(min_df=1)
ex_corpus = np.array(['This is the first document.',
          'This is the second second document.',
          'And the third one.',
          'Is this the first document?'])
ex_X = ex_vectorizer.fit_transform(ex_corpus)
ex_X
# Out:
# <4x9 sparse matrix of type '<class 'numpy.int64'>'
# 	with 19 stored elements in Compressed Sparse Row format>

# %%
ex_vectorizer.get_feature_names()
# Out:
# ['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third', 'this']

# %%
ex_X.toarray().sum(axis=0)
# Out:
# array([1, 3, 2, 3, 1, 2, 4, 1, 3], dtype=int64)

# %% [markdown]
# ### apply

# %%
raw_text = pd.read_csv('./dataframes/phone_fullframe(title_only).csv', encoding='utf-8')
raw_text['contents'] = raw_text['title'] + ' ' + raw_text['content']
del raw_text['title']
del raw_text['content']
corpus = np.array(raw_text['contents'])
print(len(corpus))
print(corpus[0:3])

raw_text.tail()
# Out:
# 23755
# ['g5 친구 끼리끼리 추천 이벤트 합니다. 저의 추천 코드는 : g5-cv74b 입니다.'
#  'ㅅㅋㄱㅂ g5 40이 안뜨네요. 더 기다립니다.'
#  '[g5] 어제 네이버 지도랑 전화부 어플 켰을 때 데이터통신 안 되던게 그래서였나 자꾸 진입 못 하고 로딩상태에서 계속 머무르더라구요. 근데 오늘 g5 데이터통신 관련 소프트웨어 결함 기사...ㅋㅋㅋㅋ 근데 웃긴 건 다른 어플이나 인터넷할 땐 데이터 잘 됐는데 저 두 어플만 안 됐다는 거. 그리고 오늘 다시 실행해보니 또 됨. -_- 허허허']
#                                                       id    date product  \
# 23750  http://www.ppomppu.co.kr/zboard/view.php?id=ph...  170401      g6
# 23751  http://www.ppomppu.co.kr/zboard/view.php?id=ph...  170401      g6
# 23752  http://www.ppomppu.co.kr/zboard/view.php?id=ph...  170401      g6
# 23753  http://www.ppomppu.co.kr/zboard/view.php?id=ph...  170401      g6
# 23754  http://www.ppomppu.co.kr/zboard/view.php?id=ph...  170401      g6
#
#            ref                                           contents
# 23750  ppomppu  G6 약 그라데이션+붉은액정 a/s 후기  섭센터 가서 보여주니 기사 본인은 비슷해...
# 23751  ppomppu  목요일 개통한 G6 배터리 상태가 이상한거 같습니다.  ? ? 제가 개통한건 아니고...
# 23752  ppomppu  S8과 G6 사은품 팔려고생각하면 G6가 더 낫네요.  S8 - 레벨박스 스피커 +...
# 23753  ppomppu  g6 홈 터치 버튼 좀 알려주세여 ㅠㅠ  추가하려고 설정에 가봐도 세줄짜리 메뉴버튼...
# 23754  ppomppu  G6 미라캐스트(미러링) 되는지요?  미라캐스트 가능한지요? 삼성은 미러링 엘지는 ...

# %%
vectorizer = CountVectorizer(min_df = 0.001, token_pattern=r'\w+')
X = vectorizer.fit(corpus)
X_t = vectorizer.fit_transform(corpus)
X_t
# Out:
# <33502x3061 sparse matrix of type '<class 'numpy.int64'>'
# 	with 707649 stored elements in Compressed Sparse Row format>

# %%
print(len(X.vocabulary_))
print(len(vectorizer.get_feature_names()))
vectorizer.get_feature_names()
# Out:
# 3061
# 3061
# ['114',
#  '11번가',
#  '20',
#  '20대',
#  '29요금제',
#  '2년약정',
#  '30대',
#  '32g',
#  '32gb',
#  '35mm',
#  '3d',
#  '3g',
#  '4g',
#  '4gb',
#  '4k',
#  '4s',
#  '5',
#  '50',
#  '51요금제',
#  '59',
#  '599',
#  '599요금제',
#  '59요금',
#  '59요금제',
#  '5s',
#  '5x',
#  '64g',
#  '64gb',
#  '6p',
#  '6s',
#  '6개월유',
#  '7엣지',
#  '9요금제',
#  'a',
#  'a3',
#  'a5',
#  'a7',
#  'a8',
#  'af',
#  'aid',
#  'always',
#  'and',
#  'aod',
#  'ap',
#  'as',
#  'auto',
#  'average',
#  'b',
#  'be',
#  'by',
#  'c',
#  'camera',
#  'cat',
#  'cat6',
#  'centre',
#  'cj',
#  'co',
#  'com',
#  'compulsory',
#  'cpu',
#  'd',
#  'dac',
#  'dap',
#  'daum',
#  'dc',
#  'display',
#  'do',
#  'dslr',
#  'e',
#  'edge',
#  'equiv',
#  'ev',
#  'f1',
#  'f2',
#  'feat',
#  'fhd',
#  'fi',
#  'fired',
#  'flac',
#  'flash',
#  'for',
#  'freeboard',
#  'from',
#  'g',
#  'g2',
#  'g3',
#  'g4',
#  'g5',
#  'g50',
#  'g530',
#  'g5나',
#  'g5보',
#  'g5사',
#  'g5중',
#  'g6',
#  'g6사',
#  'g7',
#  'galaxy',
#  'gps',
#  'gpu',
#  'h',
#  'h3',
#  'hbs',
#  'hd',
#  'hdr',
#  'hi',
#  'hifi',
#  'htc',
#  'html',
#  'http',
#  'https',
#  'i',
#  'i5',
#  'in',
#  'ios',
#  'ios7',
#  'ip68',
#  'iphone',
#  'ips',
#  'iso',
#  'it',
#  'j5',
#  'j7',
#  'jpg',
#  'k',
#  'kb',
#  'kr',
#  'kt',
#  'l',
#  'lcd',
#  'led',
#  'lg',
#  'lgu',
#  'ls2d',
#  'lte',
#  'm',
#  'mc',
#  'mid',
#  'mode',
#  'mp3',
#  'mwc',
#  'n',
#  'naver',
#  'net',
#  'news',
#  'nfc',
#  'nhn',
#  'no',
#  'normal',
#  'not',
#  'note',
#  'o',
#  'of',
#  'official',
#  'oid',
#  'ois',
#  'on',
#  'or',
#  'os',
#  'p',
#  'pc',
#  'phone',
#  'phonearena',
#  'play',
#  'plus',
#  'pro',
#  'ps',
#  'q',
#  'qc',
#  'qhd',
#  'r',
#  'ram',
#  's',
#  's2',
#  's3',
#  's4',
#  's5',
#  's6',
#  's6엣지',
#  's7',
#  's7edge',
#  's7사',
#  's7엣',
#  's7엣지',
#  's7플랫',
#  's8',
#  's9',
#  'samsung',
#  'sd',
#  'se',
#  'sid1',
#  'sid2',
#  'sk',
#  'skt',
#  'sm',
#  'sns',
#  'ssd',
#  't',
#  'the',
#  'tistory',
#  'to',
#  'tv',
#  'txt',
#  'type',
#  'u',
#  'uhd',
#  'ui',
#  'usb',
#  'v',
#  'v10',
#  'v20',
#  'v30',
#  'vr',
#  'vs',
#  'wav',
#  'wb',
#  'weighted',
#  'with',
#  'x',
#  'y',
#  'youtube',
#  'z',
#  'ㄱ',
#  'ㄱㅂ',
#  'ㄱㅂㅌㅋㄴ',
#  'ㄲㄷㅂ',
#  'ㄲㅂㄷ',
#  'ㄴ',
#  'ㄷ',
#  'ㄷㄷ',
#  'ㄷㄷㄷ',
#  'ㄷㄷㄷㄷ',
#  'ㄷㄷㄷㄷㄷ',
#  'ㄹ',
#  'ㄹㄱ',
#  'ㄹㄱㄱㅂ',
#  'ㄹㄱㅂㅇ',
#  'ㄹㅇ',
#  'ㅂ',
#  'ㅂㄷ',
#  'ㅂㅇ',
#  'ㅃㅅ',
#  'ㅅ',
#  'ㅅㄴㅂ',
#  'ㅅㄷㄹ',
#  'ㅅㅂ',
#  'ㅅㅋ',
#  'ㅅㅋㄱㅂ',
#  'ㅅㅋㅂㅇ',
#  'ㅅㅌㅊ',
#  'ㅆㅅㅌ',
#  'ㅆㅅㅌㅊ',
#  'ㅇ',
#  'ㅇㅇ',
#  'ㅇㅈ',
#  'ㅈ',
#  'ㅈㄱ',
#  'ㅊ',
#  'ㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋ',
#  'ㅋㅌ',
#  'ㅋㅌㄱㅂ',
#  'ㅋㅌㅂㅇ',
#  'ㅌㅋㄴ',
#  'ㅌㅋㄴㅁㅌ',
#  'ㅍㅇㅂ',
#  'ㅍㅌㅊ',
#  'ㅎ',
#  'ㅎㄷㄷ',
#  'ㅎㅇ',
#  'ㅎㅎ',
#  'ㅎㅎㅎ',
#  'ㅎㅎㅎㅎ',
#  '가',
#  '가개통',
#  '가게',
#  '가격',
#  '가격대',
#  '가격차이',
#  '가고',
#  '가기',
#  '가까이',
#  '가깝',
#  '가끔',
#  '가늘',
#  '가능',
#  '가능성',
#  '가도',
#  '가라',
#  '가량',
#  '가려',
#  '가로',
#  '가면',
#  '가방',
#  '가볍다',
#  '가보',
#  '가성비',
#  '가시',
#  '가야',
#  '가운데',
#  '가입',
#  '가자',
#  '가장',
#  '가정',
#  '가족',
#  '가죽',
#  '가지',
#  '가치',
#  '각',
#  '각각',
#  '각도',
#  '각자',
#  '각종',
#  '간',
#  '간간',
#  '간단',
#  '간략',
#  '간만',
#  '간섭',
#  '간지',
#  '간혹',
#  '갈',
#  '갈등',
#  '갈리',
#  '갈수',
#  '감',
#  '감사',
#  '감사하겠습',
#  '감상',
#  '감성',
#  '감안',
#  '감이',
#  '감탄',
#  '갑',
#  '값',
#  '갓',
#  '강력',
#  '강변',
#  '강제',
#  '강조',
#  '강하',
#  '강화',
#  '갖',
#  '같',
#  '같긴',
#  '같긴한데',
#  '같습',
#  '같은거',
#  '개',
#  '개념',
#  '개발',
#  '개발자',
#  '개봉',
#  '개선',
#  '개씹',
#  '개이',
#  '개인',
#  '개인적',
#  '개철',
#  '개취',
#  '개통',
#  '개통이',
#  '개판',
#  '객관적',
#  '갠',
#  '갤',
#  '갤2',
#  '갤3',
#  '갤4',
#  '갤5',
#  '갤6',
#  '갤7',
#  '갤7엣지',
#  '갤8',
#  '갤s6',
#  '갤s7',
#  '갤s7엣지',
#  '갤s8',
#  '갤노트5',
#  '갤러리',
#  '갤럭시',
#  '갤럭시7',
#  '갤럭시s',
#  '갤럭시s4',
#  '갤럭시s5',
#  '갤럭시s6',
#  '갤럭시s7',
#  '갤럭시s7엣지',
#  '갤럭시s8',
#  '갤럭시노트5',
#  '갤럭키',
#  '갤세븐',
#  '갤오광',
#  '갤칠',
#  '갤탭',
#  '거',
#  '거기',
#  '거래',
#  '거리',
#  '거울',
#  '거의',
#  '거지',
#  '거진',
#  '거치대',
#  '걱정',
#  '건가',
#  '건지',
#  '걸',
#  '걸리',
#  '검',
#  '검사',
#  '검색',
#  '검은색',
#  '겁',
#  '것',
#  '겉',
#  '게',
#  '게다',
#  '게시',
#  '게시물',
#  '게시판',
#  '게이',
#  '게임',
#  '겔럭시',
#  '겜',
#  '겠',
#  '겠네',
#  '겨',
#  '견적',
#  '결과',
#  '결과물',
#  '결국',
#  '결론',
#  '결론적',
#  '결정',
#  '결제',
#  '결함',
#  '결합',
#  '경기',
#  '경우',
#  '경쟁',
#  '경쟁력',
#  '경험',
#  '계',
#  '계산',
#  '계산기',
#  '계속',
#  '계시',
#  '계신',
#  '계실',
#  '계약',
#  '계약서',
#  '계획',
#  '고',
#  '고가',
#  '고객',
#  '고객센터',
#  '고급',
#  '고려',
#  '고로',
#  '고르',
#  '고릴라',
#  '고맙',
#  '고민',
#  '고사양',
#  '고생',
#  '고성능',
#  '고속',
#  '고수',
#  '고싶',
#  '고음질',
#  '고장',
#  '고정',
#  '고화질',
#  '곡면',
#  '곡선',
#  '골',
#  '골드',
#  '곳',
#  '공간',
#  '공개',
#  '공급',
#  '공기계',
#  '공기기',
#  '공부',
#  '공시',
#  '공시가',
#  '공식',
#  '공유',
#  '공장',
#  '공정',
#  '공지',
#  '공짜',
#  '공초',
#  '과',
#  '과감',
#  '과거',
#  '과정',
#  '관건',
#  '관계',
#  '관계자',
#  '관련',
#  '관리',
#  '관심',
#  '관한',
#  '관해',
#  '광각',
#  '광각렌즈',
#  '광고',
#  '광주',
#  '광탈',
#  '괜찮다',
#  '굉장',
#  '교체',
#  '교체형',
#  '교품',
#  '교품받',
#  '교품증',
#  '교품하',
#  '교품해',
#  '교환',
#  '구',
#  '구경',
#  '구경하',
#  '구글',
#  '구동',
#  '구라',
#  '구라베젤',
#  '구리',
#  '구매',
#  '구매가',
#  '구매자',
#  '구멍',
#  '구분',
#  '구사',
#  '구성',
#  '구입',
#  '구입시',
#  '구조',
#  '구하',
#  '구해',
#  '구현',
#  '구형',
#  '국내',
#  '국민',
#  '국민카드',
#  '굳',
#  '굴곡',
#  '굿',
#  '궁금',
#  '귀',
#  '귀에',
#  '귀찮다',
#  '그',
#  '그간',
#  '그걸',
#  '그게',
#  '그나',
#  '그동안',
#  '그때',
#  '그라데이션',
#  '그래픽',
#  '그래픽카드',
#  '그러',
#  '그런거',
#  '그럼',
#  '그르',
#  '그림',
#  '그립',
#  '그립감',
#  '그만',
#  '그만큼',
#  '그이',
#  '그자',
#  '그저',
#  '그전',
#  '그정',
#  '그제',
#  '그중',
#  '극',
#  '극혐',
#  '근대',
#  '근데',
#  '근래',
#  '근접',
#  '근처',
#  '글',
#  '글래스',
#  '글로벌',
#  '글보',
#  '글자',
#  '금',
#  '금방',
#  '금속',
#  '금액',
#  '금요일',
#  '금일',
#  '금제',
#  '급',
#  '급속',
#  '급하',
#  '기',
#  '기가',
#  '기간',
#  '기계',
#  '기기',
#  '기념',
#  '기능',
#  '기능인',
#  '기다',
#  '기다리기',
#  '기대',
#  '기대감',
#  '기도',
#  '기록',
#  '기반',
#  '기변',
#  '기본',
#  '기본기',
#  '기본적',
#  '기분',
#  '기사',
#  '기술',
#  '기술력',
#  '기스',
#  '기어',
#  '기어s2',
#  '기어vr',
#  '기억',
#  '기업',
#  '기울',
#  '기존',
#  '기종',
#  '기준',
#  '기타',
#  '기프트',
#  '기회',
#  '긴',
#  '길',
#  '길어',
#  '길이',
#  '김',
#  '까운',
#  '까이',
#  '까지',
#  '깔끔',
#  '깜빡',
#  '깨끗',
#  '깨지',
#  '꺼지',
#  '껄',
#  '껴',
#  '꼴',
#  '꼽',
#  '꽂',
#  '꽤',
#  '꾸준',
#  '꿈',
#  '끈',
#  '끌',
#  '끌리다',
#  '끝',
#  '끼',
#  '끼리',
#  '끼우',
#  '나',
#  '나간',
#  '나머지',
#  '나면',
#  '나쁘다',
#  '나아',
#  '나오기',
#  '나오는거',
#  '나온거',
#  '나올',
#  '나와',
#  '나을',
#  '나음',
#  '나이',
#  '나중',
#  '나지',
#  '나타',
#  '난',
#  '난감',
#  '난리',
#  '날',
#  '날씨',
#  '날짜',
#  '남',
#  '남기',
#  '남아',
#  '남자',
#  '납부',
#  '낫',
#  '낮',
#  '내',
#  '내가',
#  '내고',
#  '내구성',
#  '내년',
#  '내리',
#  '내면',
#  '내방',
#  '내부',
#  '내야',
#  '내외',
#  '내용',
#  '내일',
#  '내일부',
#  '내장',
#  '내장형',
#  '내주',
#  '낼',
#  '냐',
#  '너무',
#  '넉넉',
#  '넓',
#  '넘',
#  '넘사벽',
#  '네',
#  '네비',
#  '네이버',
#  '네트워크',
#  '넥서스',
#  '넥서스5x',
#  '녀',
#  '녀석',
#  '노',
#  '노래',
#  '노력',
#  '노리',
#  '노무',
#  '노예',
#  '노이즈',
#  '노출',
#  '노크',
#  '노트',
#  '노트2',
#  '노트3',
#  '노트4',
#  '노트4s',
#  '노트5',
#  '노트6',
#  '노트7',
#  '노트북',
#  '녹음',
#  '논란',
#  '놀',
#  '놀랍',
#  '놈',
#  '놋5',
#  '높',
#  '높이',
#  '놓',
#  '누',
#  '누가',
#  '누구',
#  '누나',
#  '누렇',
#  '누르',
#  '눈',
#  '눈치',
#  '눈팅',
#  '뉴스',
#  '느끼',
#  '느낀점',
#  '느낌',
#  '느리다',
#  '늘',
#  '늘리',
#  '능',
#  '능력',
#  '늦다',
#  '니',
#  '닐',
#  '님',
#  '다',
#  '다니',
#  '다되',
#  '다들',
#  '다르',
#  '다르지',
#  '다른',
#  '다른거',
#  '다른폰',
#  '다름',
#  '다면',
#  '다소',
#  '다시',
#  '다양',
#  '다운',
#  '다운그레이드',
#  '다운로드',
#  '다음',
#  '다음날',
#  '다음달',
#  '다음주',
#  '다이렉트',
#  '다행',
#  '닥',
#  '단',
#  '단가',
#  '단단',
#  '단말',
#  '단말기',
#  '단순',
#  '단어',
#  '단자',
#  '단점',
#  '단지',
#  '단차',
#  '단통법',
#  '달',
#  '달고',
#  '달라',
#  '달리',
#  '달린',
#  '담',
#  '담주',
#  '답',
#  '답답',
#  '답변',
#  '답인',
#  '당',
#  '당분간',
#  '당시',
#  '당연',
#  '당일',
#  '당장',
#  '당첨',
#  '당하',
#  '당한',
#  '당황',
#  '대',
#  '대구',
#  '대기',
#  '대다수',
#  '대단',
#  '대답',
#  '대란',
#  '대략',
#  '대략적',
#  '대로',
#  '대리점',
#  '대만족',
#  '대박',
#  '대부분',
#  '대비',
#  '대상',
#  '대세',
#  '대신',
#  '대안',
#  '대용량',
#  '대응',
#  '대전',
#  '대체',
#  '대충',
#  '대폭',
#  '대해',
#  '대화면',
#  '댓글',
#  '더',
#  '더니',
#  '더럽',
#  '더이',
#  '더하',
#  '덕분',
#  '덜',
#  '데',
#  '데이터',
#  '데이트',
#  '도',
#  '도대',
#  '도색',
#  '도와',
#  '도움',
#  '도입',
#  '도장',
#  '도저',
#  '도전',
#  '도중',
#  '도착',
#  '돈',
#  '돌',
#  '돌리',
#  '동급',
#  '동네',
#  '동료',
#  '동생',
#  '동시',
#  '동안',
#  '동영상',
#  '동일',
#  '동작',
#  '되',
#  '되기',
#  '되는거',
#  '되지',
#  '된거',
#  '될거',
#  '됨',
#  '두',
#  '두가',
#  '두개',
#  '두꺼',
#  '두껍',
#  '두께',
#  '두배',
#  '두운',
#  '둘',
#  '둘이',
#  '둘째',
#  '둥글',
#  '뒤',
#  '뒷면',
#  '뒷판',
#  '듀얼',
#  '드',
#  '드라마',
#  '드라이버',
#  '드러',
#  '드리',
#  '드릴',
#  '드립',
#  '듣기',
#  '들',
#  '들림',
#  '들어있',
#  '들이',
#  '듯하',
#  '등',
#  '등급',
#  '등등',
#  '등록',
#  '등에',
#  '등이',
#  '등장',
#  '디',
#  '디바이스',
#  '디스플레이',
#  '디자인',
#  '디자인과',
#  '디지털',
#  '디지털프라자',
#  '디카',
#  '디테일',
#  '디플',
#  '딜',
#  '딱',
#  '딴',
#  '때',
#  '땡기',
#  '떨',
#  '떨어짐',
#  '떨어트',
#  '떰',
#  '떼',
#  '또',
#  '똑같',
#  '똥',
#  '뛰',
#  '뜨',
#  '뜨겁다',
#  '뜬금없',
#  '뜸',
#  '뜻',
#  '띄',
#  '라',
#  '라리',
#  '라오',
#  '라이트',
#  '라인',
#  '랑',
#  '램',
#  '런',
#  '럼',
#  '레노버',
#  '레이',
#  '레이저',
#  '렉',
#  '렌더링',
#  '렌즈',
#  '려고',
#  '로',
#  '로고',
#  '로딩',
#  '로즈골드',
#  '롯데',
#  '롯데카드',
#  '루머',
#  '르',
#  '르그',
#  '를',
#  '리',
#  '리베이트',
#  '리뷰',
#  '리시버',
#  '리퍼',
#  ...]

# %%
word_sum = X_t.toarray().sum(axis=0)
word_name = vectorizer.get_feature_names()
word_dict = {}

for i in range(len(word_sum)):
    word_dict[word_name[i]] = word_sum[i]

# %%
print(vectorizer.get_feature_names()[150:160])
print(word_sum[150:160])
# Out:
# ['note', 'o', 'of', 'official', 'oid', 'ois', 'on', 'or', 'os', 'p']
# [ 56 553 186 501 268  53 174 272 133 631]

# %%
word_dict
# Out:
# {'전달': 62,
#  '인증': 208,
#  '금일': 38,
#  '달고': 144,
#  '뜨': 2399,
#  '기도': 34,
#  '보정': 160,
#  '다음': 533,
#  '부1': 55,
#  '꿈': 37,
#  '이런걸': 51,
#  's7엣': 38,
#  '자전거': 54,
#  '쓰레기': 171,
#  'youtube': 176,
#  '5s': 137,
#  '측정': 131,
#  '선택지': 45,
#  '쏙': 39,
#  '능력': 46,
#  '반면': 87,
#  '부족': 312,
#  '주': 481,
#  '로': 957,
#  '편리': 122,
#  '스냅드래곤': 203,
#  'mwc': 145,
#  '확보': 51,
#  '양해': 42,
#  '아깝': 91,
#  '예민': 57,
#  '상향': 67,
#  '주요': 64,
#  '집': 526,
#  '교품하': 77,
#  '쿼드비트': 49,
#  '가야': 242,
#  '누': 69,
#  '양호': 52,
#  '못하': 1081,
#  '시크릿': 133,
#  'ㅇㅇ': 130,
#  'cat6': 53,
#  '진짜': 1684,
#  '프리미엄': 223,
#  '녹음': 65,
#  '추천': 1354,
#  '컴터': 62,
#  '대전': 84,
#  '셔터': 76,
#  '주로': 223,
#  '들': 525,
#  '공기계': 457,
#  '답': 323,
#  '내년': 97,
#  '의미': 224,
#  '연동': 70,
#  '고민': 2579,
#  '픽셀': 65,
#  '하도': 87,
#  '너무': 257,
#  '보이': 932,
#  '골드': 605,
#  '도착': 227,
#  '누가': 66,
#  '한시': 59,
#  '대단': 120,
#  '공정': 55,
#  '인지': 62,
#  '별다르': 47,
#  '뛰': 119,
#  'aid': 242,
#  '주의': 75,
#  '본체': 217,
#  '청구': 298,
#  '주네': 39,
#  '머': 206,
#  '등등': 398,
#  '녀석': 45,
#  '간혹': 48,
#  '비교적': 48,
#  '자': 97,
#  '하나씩': 75,
#  'camera': 48,
#  '형태': 149,
#  '오기': 41,
#  '단점': 576,
#  '하락': 69,
#  '젠더': 149,
#  '서브': 95,
#  '내주': 55,
#  '서류': 62,
#  '부착': 166,
#  '구조': 86,
#  '작동': 194,
#  '혜택': 303,
#  '띄': 87,
#  '참고': 855,
#  '심하다': 417,
#  '부문': 80,
#  '슈퍼': 51,
#  '그러': 708,
#  '베터리': 289,
#  '반납': 162,
#  '사이드': 71,
#  '에': 1470,
#  '통신사': 870,
#  '출력': 143,
#  '살짝': 440,
#  '스스로': 44,
#  '속': 104,
#  '뽑기': 161,
#  '무부': 160,
#  '59요금': 43,
#  '옆면': 62,
#  '번호': 751,
#  '교품받': 53,
#  '유리': 278,
#  '게시': 63,
#  '아임백': 84,
#  '직전': 49,
#  '밴드59': 51,
#  '쓰': 8830,
#  '사기': 356,
#  '사랑': 60,
#  '카메라': 4236,
#  '보지': 71,
#  '계': 112,
#  '결론': 301,
#  '덕분': 118,
#  '경험': 168,
#  '갤럭시s6': 198,
#  'd': 83,
#  '32g': 336,
#  '부탁': 1240,
#  '디자인과': 61,
#  '아재': 56,
#  '향후': 49,
#  '말로': 72,
#  'and': 278,
#  '비교': 1500,
#  '불량': 978,
#  '마감': 278,
#  '축소': 49,
#  '그래픽': 108,
#  '헤드셋': 107,
#  '몰레': 458,
#  'ㅎㅎㅎㅎ': 36,
#  '어이': 40,
#  '보유': 52,
#  '있습': 79,
#  '환경': 135,
#  '돈': 462,
#  '인기': 147,
#  '말': 1789,
#  '세': 105,
#  '갤7': 2310,
#  '온도': 117,
#  '로즈골드': 50,
#  '무겁다': 104,
#  '카페': 135,
#  '생활': 72,
#  'af': 84,
#  '본인': 175,
#  '호환': 231,
#  '색상': 820,
#  '시기': 154,
#  '하나': 910,
#  'ps': 126,
#  '주제': 64,
#  '액티브': 48,
#  '개발': 163,
#  '중심': 45,
#  '점': 448,
#  '쿼드': 64,
#  '확정기': 129,
#  '뒷판': 125,
#  'display': 51,
#  'sid1': 264,
#  '해지': 310,
#  '우리나라': 53,
#  '특성상': 47,
#  '와이프': 290,
#  '통신': 76,
#  '나오는거': 87,
#  '듣기': 53,
#  '조합': 139,
#  '아닌거': 78,
#  '고화질': 44,
#  '실사용': 225,
#  's': 469,
#  '갤3': 76,
#  '당하': 97,
#  '드릴': 86,
#  '당일': 240,
#  '친절': 127,
#  '끼리': 85,
#  '반값': 49,
#  '폰사': 65,
#  'h': 171,
#  '결론적': 55,
#  '겉': 41,
#  '뽐': 200,
#  '고르': 130,
#  '교품증': 317,
#  '놈': 171,
#  '등이': 69,
#  '번거': 49,
#  '견적': 112,
#  '경기': 39,
#  '멀': 217,
#  '이득': 191,
#  '소소': 39,
#  'ㄱㅂㅌㅋㄴ': 263,
#  '고맙': 38,
#  '다들': 727,
#  '안': 2614,
#  '여기': 415,
#  '무려': 51,
#  '귀찮다': 323,
#  '완료': 127,
#  'from': 97,
#  '뭘까': 51,
#  '핑크색': 52,
#  '참여': 119,
#  '그럼': 63,
#  '여': 410,
#  '통수': 46,
#  '다름': 59,
#  '난리': 78,
#  '첫번': 98,
#  '4gb': 76,
#  '작은': 275,
#  'g5사': 115,
#  '발전': 138,
#  '진동': 246,
#  '열': 90,
#  '느끼': 197,
#  'ㅂ': 87,
#  '버스': 95,
#  '별로': 475,
#  '이점': 51,
#  '스냅820': 105,
#  '실시간': 55,
#  '웬만': 37,
#  '칩셋': 59,
#  '팔리': 149,
#  '짓': 60,
#  '우레탄': 84,
#  '그정': 89,
#  '아이디어': 76,
#  '음악감상': 56,
#  '노트4': 360,
#  '중고가': 209,
#  '막': 332,
#  '으': 269,
#  '두운': 51,
#  '베시': 202,
#  '당분간': 70,
#  'mc': 78,
#  '업그레이드': 240,
#  '드립': 224,
#  '뭐하': 133,
#  '기업': 176,
#  '기본': 897,
#  '한가': 53,
#  '멀쩡': 82,
#  '확인': 1140,
#  '빠진': 98,
#  '오후': 139,
#  '네트워크': 59,
#  '소재': 45,
#  'ㄷㄷ': 335,
#  '화면': 2169,
#  '한글': 57,
#  '이라': 399,
#  '딴': 91,
#  'l': 62,
#  '쪽지': 220,
#  '분도': 49,
#  '약하': 57,
#  '린다': 78,
#  '갤s7': 1503,
#  '기회': 94,
#  '하는거': 113,
#  'iso': 265,
#  'se': 245,
#  '지난주': 86,
#  '알고': 218,
#  '후반': 78,
#  '전략': 181,
#  '카드사': 56,
#  '어가': 625,
#  '배트맨': 70,
#  '먼저': 292,
#  '유': 48,
#  '뭘': 77,
#  '보조배터리': 221,
#  '조금': 268,
#  '되는거': 137,
#  '아이폰se': 143,
#  '환불': 110,
#  '형님': 75,
#  '안보': 367,
#  '추가': 931,
#  'z': 40,
#  '일요일': 67,
#  '우리': 63,
#  '갑': 72,
#  '갤오광': 62,
#  '이런가': 36,
#  '행사': 205,
#  '팔고': 145,
#  '산지': 122,
#  '폭': 146,
#  '메일': 55,
#  '졸업': 77,
#  '삼성카드': 162,
#  '노이즈': 151,
#  '이용자': 45,
#  '할부금': 343,
#  '오디오': 180,
#  '쓸': 539,
#  '캠': 59,
#  '20대': 79,
#  '버리': 209,
#  '보임': 59,
#  '만한': 155,
#  '제': 3681,
#  '불': 66,
#  '등록': 177,
#  '쉬': 91,
#  '교체형': 123,
#  '무상': 170,
#  '양쪽': 69,
#  '이건': 839,
#  '노력': 82,
#  '마치': 143,
#  '국내': 510,
#  '음성': 82,
#  '어두': 126,
#  '한해': 37,
#  '수가': 167,
#  '포장': 46,
#  '속도': 482,
#  '한명': 49,
#  '압승': 52,
#  '힘': 356,
#  '일': 387,
#  '귀': 84,
#  'b': 487,
#  '혀': 145,
#  '즐거운': 50,
#  '단말기': 330,
#  '잠금': 150,
#  '세상': 69,
#  '나면': 75,
#  '간섭': 50,
#  '질러': 50,
#  '그전': 96,
#  '스타일': 90,
#  '아래쪽': 54,
#  '보아': 42,
#  '기어vr': 129,
#  '비롯': 39,
#  '만': 841,
#  '맛폰': 77,
#  '광고': 430,
#  '듀얼': 340,
#  '첨': 227,
#  '단지': 59,
#  '공기기': 74,
#  '잇': 70,
#  'g3': 717,
#  '영화': 184,
#  '본사': 69,
#  '높이': 85,
#  '후에': 219,
#  '꼴': 37,
#  '신청': 1088,
#  '물리': 122,
#  '손해': 128,
#  '밖': 437,
#  '맛탱이': 37,
#  '만나': 81,
#  '스피드': 38,
#  '될거': 60,
#  '지갑': 55,
#  '없을거': 40,
#  '다면': 128,
#  '설탕': 314,
#  '20': 74,
#  '예의': 53,
#  '매장': 525,
#  '노트5': 1206,
#  '무시': 84,
#  '실험': 56,
#  '같습': 107,
#  '많은': 328,
#  '원가절감': 105,
#  '먹통': 112,
#  '산다': 152,
#  '럼': 256,
#  '간간': 35,
#  'ㅎㅇ': 791,
#  '예정': 468,
#  '스크': 571,
#  'do': 61,
#  '좋다': 10989,
#  '조준호': 79,
#  '일어': 164,
#  '노크': 126,
#  's7플랫': 88,
#  '멍청': 36,
#  '터': 290,
#  '메탈': 540,
#  '일시불': 138,
#  '지투': 55,
#  '일정': 109,
#  '스마트폰': 1676,
#  '수리비': 104,
#  '하기': 217,
#  '무한': 350,
#  '아직': 1806,
#  '옴': 49,
#  '요소': 78,
#  '길이': 93,
#  '몇달': 92,
#  '중인': 176,
#  '되': 6867,
#  '등급': 63,
#  '어떨까': 55,
#  '무게': 188,
#  '궁금': 1278,
#  'of': 186,
#  '주말': 358,
#  'g50': 39,
#  '시장': 330,
#  '앞면': 57,
#  '모듈': 3473,
#  '싫다': 534,
#  '은색': 47,
#  '자가': 63,
#  '프레임': 100,
#  '현아': 676,
#  '어렵다': 401,
#  '과거': 91,
#  '나오기': 137,
#  '상단': 261,
#  'ㅂㅇ': 230,
#  '오픈': 71,
#  '올레': 276,
#  '갤러리': 110,
#  '타입': 79,
#  '하이엔드': 71,
#  '부분': 1388,
#  '소리': 803,
#  '가량': 75,
#  '모': 379,
#  'uhd': 66,
#  '오토': 45,
#  'it': 182,
#  '뒤': 531,
#  '불구': 111,
#  '제값': 43,
#  '갤럭시s4': 51,
#  '들어있': 80,
#  '적당': 342,
#  '솔': 36,
#  '잡고': 105,
#  '사업부': 62,
#  '힐링쉴드': 71,
#  '됨': 194,
#  '2년약정': 110,
#  '만지': 126,
#  '호평': 66,
#  '조기': 61,
#  '불편함': 130,
#  'n': 240,
#  '헬쥐': 155,
#  '어떤가': 419,
#  '맞고': 79,
#  '사라': 191,
#  '전용': 141,
#  '노': 300,
#  'ㅋㅌㅂㅇ': 493,
#  '예': 463,
#  '할인': 1655,
#  '주목': 47,
#  '하이파이': 919,
#  '평범': 55,
#  '매달': 156,
#  '급하': 151,
#  '부품': 197,
#  '한': 1652,
#  '게이': 234,
#  '진입': 55,
#  'ㅅㅋㅂㅇ': 485,
#  '기반': 40,
#  '엣지': 414,
#  '통': 41,
#  '거래': 89,
#  '노트3': 291,
#  '악세사리': 128,
#  '삼성서비스': 42,
#  '등에': 77,
#  '인터페이스': 51,
#  '가죽': 52,
#  '핸폰': 91,
#  '전화': 984,
#  '옥션': 257,
#  '서': 341,
#  '문득': 51,
#  '사면': 502,
#  '낮': 441,
#  '플리커': 57,
#  '허리': 84,
#  '금속': 74,
#  'g2': 783,
#  '같': 8532,
#  '제발': 201,
#  '조치': 39,
#  '설마': 116,
#  '내장형': 47,
#  '마무리': 55,
#  '29요금제': 52,
#  '싸구려': 84,
#  '일반인': 102,
#  '중반': 57,
#  '면제': 43,
#  '쓰는거': 50,
#  '착탈식': 68,
#  '카카오톡': 45,
#  '모아': 56,
#  '그자': 39,
#  '안되다': 1736,
#  '공초': 65,
#  '배송비': 46,
#  '각': 115,
#  '전산': 68,
#  '최초': 152,
#  '페이지': 81,
#  'official': 501,
#  '함': 547,
#  '구매': 3480,
#  '패드': 76,
#  '후면': 746,
#  '보기': 279,
#  '핑골': 44,
#  '같긴': 62,
#  '집중': 70,
#  '답답': 207,
#  '밤': 51,
#  '검은색': 65,
#  '놓': 423,
#  '구매가': 84,
#  '접근': 57,
#  '가능성': 252,
#  '유플러스': 352,
#  '제공': 358,
#  '평소': 161,
#  '출시일': 178,
#  '옛날': 84,
#  '조건': 1376,
#  '7엣지': 109,
#  '사과': 92,
#  '반응': 239,
#  '가성비': 378,
#  '번들이어폰': 62,
#  '조리개': 54,
#  '당첨': 112,
#  '표준': 52,
#  '안가': 110,
#  '택배': 333,
#  '구매자': 132,
#  '빛': 120,
#  '오프라인': 130,
#  '전송': 58,
#  '르': 2143,
#  '포함': 330,
#  '내부': 152,
#  '스티커': 55,
#  '호불호': 65,
#  '넥서스': 123,
#  'ㅊ': 125,
#  '씨': 50,
#  '수요일': 45,
#  '컴퓨터': 269,
#  '설정': 601,
#  '휴대': 43,
#  '갤탭': 42,
#  'ㅎㅎㅎ': 191,
#  '절반': 70,
#  '시계': 100,
#  'lcd': 185,
#  '아이폰6s': 489,
#  '가운데': 111,
#  '순정': 104,
#  '함정': 58,
#  '리베이트': 60,
#  '뭐': 1270,
#  '출고가': 931,
#  '떨어짐': 44,
#  '장난': 118,
#  '고객': 365,
#  '꺼지': 149,
#  '안쪽': 61,
#  '울': 35,
#  '왜': 149,
#  '플랫': 727,
#  'ㅈ': 68,
#  '가치': 116,
#  '후': 966,
#  'fi': 107,
#  '정신': 126,
#  '방탄': 71,
#  '갈수': 57,
#  '갤4': 67,
#  '조금더': 46,
#  '색깔': 91,
#  '성격': 57,
#  'wb': 212,
#  '보급형': 246,
#  '전화기': 44,
#  '잠깐': 194,
#  '이번달': 86,
#  '이기': 209,
#  '정보': 924,
#  '사는거': 72,
#  '깔끔': 303,
#  '안녕': 643,
#  '홈': 208,
#  '크': 4266,
#  'vs': 1505,
#  '신고': 52,
#  '총': 261,
#  '태블릿': 88,
#  '감사하겠습': 87,
#  '유투브': 114,
#  '결함': 187,
#  'e': 551,
#  '보자': 87,
#  '장착': 311,
#  '임': 333,
#  '흐리': 70,
#  '사실상': 160,
#  '극혐': 108,
#  '케이티': 55,
#  '휴대폰': 1194,
#  '일하': 49,
#  '센서': 261,
#  'tv': 222,
#  'ㅍㅌㅊ': 134,
#  '바람': 91,
#  '방법': 725,
#  '갈': 172,
#  '매니아': 40,
#  '오버': 42,
#  '어색': 47,
#  '흥미': 47,
#  '엑시노스': 122,
#  '전화로': 41,
#  '일본': 87,
#  '베젤': 310,
#  '논란': 122,
#  '모니터': 131,
#  '옆': 324,
#  '였습니': 46,
#  '편한': 83,
#  '정가': 63,
#  '만약': 338,
#  '하길': 104,
#  '이에': 75,
#  '스펙': 602,
#  '플래그쉽': 345,
#  '닥': 93,
#  '조루': 109,
#  '짱깨': 50,
#  '우': 103,
#  '둘': 920,
#  '통화': 431,
#  '때': 1485,
#  'g4': 1337,
#  '완충': 114,
#  'to': 204,
#  '보조': 58,
#  'ui': 140,
#  '보더': 34,
#  '보여': 441,
#  '여행': 106,
#  '갈등': 41,
#  '내일부': 47,
#  '당한': 38,
#  'average': 136,
#  '구글': 366,
#  '분': 1910,
#  '캡쳐': 66,
#  '언급': 156,
#  '바탕': 86,
#  '방금': 302,
#  '사운드': 189,
#  '연장': 95,
#  '물': 128,
#  '안함': 37,
#  'naver': 435,
#  '저기': 62,
#  '민감': 107,
#  '스트레스': 122,
#  '중입': 135,
#  '잔상': 215,
#  '밝': 328,
#  '약정기간': 65,
#  '있는거': 155,
#  '발': 348,
#  '사려': 557,
#  '아무것': 155,
#  '보조금': 151,
#  '깨끗': 114,
#  '차이나': 102,
#  'ㅅ': 103,
#  '밤에': 96,
#  '진심': 87,
#  '충분': 382,
#  'for': 188,
#  '복지': 52,
#  'pro': 94,
#  '파': 137,
#  '하세': 83,
#  '저녁': 155,
#  '취향': 164,
#  '지속적': 40,
#  '보네': 93,
#  'f2': 85,
#  '더하': 102,
#  '인해': 130,
#  '서비스센터': 452,
#  '가까이': 78,
#  '갤세븐': 46,
#  '면': 270,
#  '판매자': 295,
#  '가방': 54,
#  '가끔': 260,
#  '케이블': 277,
#  '부모님': 250,
#  '근래': 37,
#  '이하': 121,
#  '갓': 41,
#  'g': 531,
#  '끌': 43,
#  '단자': 139,
#  '강화': 600,
#  '예쁘다': 298,
#  '제외': 267,
#  '요새': 194,
#  '폰팔': 120,
#  '기프트': 209,
#  '테마': 64,
#  '정품': 184,
#  '외국': 63,
#  '올림': 41,
#  '다른거': 69,
#  '멜론': 61,
#  '활동': 43,
#  '요': 8620,
#  '6s': 477,
#  '도대': 126,
#  '발표': 268,
#  '퀵차': 131,
#  '유용': 115,
#  '좌표': 416,
#  '나머지': 268,
#  '현재': 1543,
#  'skt': 856,
#  '아시': 284,
#  '오니': 38,
#  '더럽': 36,
#  '발목': 49,
#  '은은': 36,
#  '인거': 55,
#  '제조사': 252,
#  '분위기': 180,
#  '메뉴': 107,
#  '무이자': 97,
#  '신세계': 129,
#  '화소': 219,
#  '분석': 84,
#  '깜빡': 44,
#  'with': 157,
#  '오른쪽': 207,
#  '인정': 158,
#  '본': 297,
#  '아이폰5': 101,
#  '현장': 67,
#  '생긴': 115,
#  '뭔가': 721,
#  '그게': 280,
#  '있긴': 98,
#  '장': 56,
#  '방문': 371,
#  '아탈': 104,
#  '완납': 240,
#  '완전': 536,
#  '이거': 1646,
#  '못느끼': 49,
#  '애매': 180,
#  '수정': 191,
#  '분리': 197,
#  '고릴라': 108,
#  'http': 1403,
#  '허접': 36,
#  '싼거': 68,
#  '책상': 36,
#  '요번': 84,
#  '짝': 44,
#  '손님': 48,
#  '이어': 212,
#  '소식': 155,
#  '커버': 438,
#  '전부': 410,
#  '주문': 344,
#  '반대': 88,
#  '의외': 114,
#  '튼튼': 88,
#  '긴': 319,
#  '매번': 108,
#  '웃기': 41,
#  '여부': 56,
#  '핑크': 680,
#  '입장': 205,
#  '볼륨': 231,
#  '광각렌즈': 70,
#  '셀카': 176,
#  '출근': 48,
#  '계획': 138,
#  '재질': 157,
#  'co': 336,
#  '카톡': 444,
#  '조회': 68,
#  '두껍': 105,
#  '국민': 52,
#  '연결': 621,
#  '생기': 288,
#  '공짜': 186,
#  '인터넷': 1276,
#  '표현': 108,
#  '슼': 80,
#  '활용도': 43,
#  '찬양': 46,
#  '펌업': 57,
#  '안주': 47,
#  '어이없': 47,
#  '요약': 114,
#  '재미': 155,
#  '베스트샵': 112,
#  '이리': 137,
#  '관리': 62,
#  '임직원': 72,
#  '폰알못': 109,
#  '각각': 114,
#  '엇보': 91,
#  '시점': 147,
#  '불가': 121,
#  'g5나': 59,
#  '홈키': 45,
#  '갤럭시': 3702,
#  '엑시': 47,
#  '통신요금': 57,
#  '명의': 75,
#  '통화품질': 76,
#  '음감': 270,
#  '인생': 36,
#  '간': 154,
#  'net': 88,
#  '추가지원': 47,
#  '쪽': 228,
#  '발송': 90,
#  '추가적': 59,
#  '겁': 79,
#  'phonearena': 45,
#  '제품': 1874,
#  '이상': 1337,
#  '배경': 90,
#  'v10': 1372,
#  '명함': 69,
#  '발매': 82,
#  '이름': 140,
#  '한계': 96,
#  '갤럭시s8': 164,
#  '지금': 3172,
#  'q': 85,
#  '사람': 1153,
#  'sm': 119,
#  'fired': 187,
#  '나온거': 58,
#  '더이': 99,
#  '디지털': 83,
#  'c': 361,
#  '자주': 303,
#  '바뀌': 187,
#  '동일': 488,
#  '전원': 444,
#  '편': 76,
#  '칭찬': 73,
#  '다시': 1708,
#  '물이': 49,
#  '매력': 82,
#  'mid': 223,
#  '갤럭시s7엣지': 391,
#  '특이': 98,
#  '걸': 340,
#  '수령': 232,
#  '지장': 60,
#  '초보': 149,
#  '아끼': 71,
#  '파워': 121,
#  '심심': 50,
#  '계속': 117,
#  '정': 136,
#  '현상': 437,
#  '조용': 98,
#  '찍': 705,
#  '조립': 66,
#  '선명': 149,
#  '있을거': 40,
#  '아침': 186,
#  '동급': 80,
#  '오줌': 65,
#  '좀': 4300,
#  '계산기': 56,
#  '검사': 53,
#  '흠': 208,
#  '등': 950,
#  '메리트': 171,
#  '새끼': 181,
#  '선방': 41,
#  'daum': 72,
#  '아참': 52,
#  '도': 301,
#  'led': 235,
#  '며': 39,
#  '심지': 141,
#  '필요': 882,
#  '문제점': 157,
#  '명기': 71,
#  '저렴': 680,
#  '티비': 179,
#  '묶': 39,
#  '차단': 58,
#  '최근': 386,
#  '절대': 218,
#  '삼성': 3961,
#  '고속': 328,
#  '나간': 35,
#  '런': 376,
#  '자동차': 84,
#  '아주': 540,
#  '반영': 61,
#  '올립': 130,
#  'dap': 47,
#  '두께': 154,
#  '끌리다': 73,
#  '무제한': 169,
#  '보호': 387,
#  '체험': 210,
#  '경우': 1110,
#  '문제': 2525,
#  '앞': 586,
#  '맘': 705,
#  '스맛폰': 59,
#  '현금': 563,
#  '한재': 66,
#  '산거': 88,
#  '프로': 174,
#  '언팩': 49,
#  '싱글': 61,
#  '엄청나': 115,
#  '이중': 60,
#  '있': 16515,
#  '6p': 42,
#  '유선': 75,
#  '빠릿빠릿': 46,
#  '더': 175,
#  '당황': 87,
#  '사후지원': 74,
#  '컬러': 60,
#  '구라베젤': 73,
#  '신뢰': 43,
#  'not': 208,
#  '운지': 55,
#  '하려': 444,
#  '늦다': 324,
#  '수동': 114,
#  '한게': 43,
#  '개이': 37,
#  '중간': 178,
#  '조절': 167,
#  '이후': 595,
#  '디자인': 2532,
#  '계시': 266,
#  '어': 866,
#  ...}

# %%
with open('csf_freq(after_para).csv', 'w') as f:  # Just use 'w' mode in 3.x
    w = csv.DictWriter(f, word_dict.keys(), delimiter=',', lineterminator='\n')
    w.writeheader()
    w.writerow(word_dict)

# %%
para_df = pd.read_csv('dataframes/pcsf_dataframe(ap).csv', encoding='cp949')
para_df.tail()
# Out:
#                                                       id    date product  \
# 33497  http://www.ilbe.com/index.php?mid=smartphone&s...  160731      s7
# 33498  http://www.ilbe.com/index.php?mid=smartphone&s...  160731      s7
# 33499  http://www.ilbe.com/index.php?mid=smartphone&s...  160731      s7
# 33500  http://www.ilbe.com/index.php?mid=smartphone&s...  160731      s7
# 33501  http://www.ilbe.com/index.php?mid=smartphone&s...  160731      s7
#
#         ref                                           contents
# 33497  ilbe  g3 에 s7엣지 갈아타 기기3년약정햇는데 약정 39만원뜸 씨1발이제 2년다써가는데...
# 33498  ilbe  갓럭시s7 카메라 경쟁 실제 카메라 보 일단 갤럭시s7 가볍 바르 이런건 살필요없다...
# 33499  ilbe                            s7 미개 vs 노트5 중고 군대가는데 끄
# 33500  ilbe  스마트폰 바꿀려는데 전문가 나와 이기 산 s6 엣지 요금 요금 데이타 안심 짜 쓰고...
# 33501  ilbe                          어제 산 갤럭시 s7 엣지 배터리 준수한거 냐

# %% [markdown]
# ### paraphrasing

# %%
da = ['좋', '힘들', '어둡', '잘되',  '나쁘', '거슬리', '즐겁', '안타깝',
        '부럽', '안되', '빠르', '부드럽', '괜찮', '심하', '잘하', '편하',
        '귀찮', '무겁', '어렵', '느리', '끌리', '오래가', '뜨겁', '비싸',
        '예쁘', '신경쓰', '새롭', '늦', '이쁘', '싫', '아쉽', '가볍']
hada = ['욕', '잘못', '망', '무난']
noun = ['고장', '짜증']

para_dict = {'para_da': da, 'para_hada': hada, 'to_noun': noun}

def paralst_create(*args):
    para_lst = []
    for lst in args:
        for i in lst:
            para_lst.append(i)
    return para_lst

para_lst = paralst_create(da, hada, noun)

# %%
for i in range(0, len(para_df)):
    for word in para_lst:
        para = re.compile(r'{}\w*'.format(word))

        if word in para_dict['para_da']:
            para_df['contents'][i] = para.sub(' {}다 '.format(word), para_df['contents'][i])

        elif word in para_dict['para_hada']:
            para_df['contents'][i] = para.sub(' {}하다 '.format(word), para_df['contents'][i])

        elif word in para_dict['to_noun']:
            para_df['contents'][i] = para.sub(' {} '.format(word), para_df['contents'][i])
# Out:
# C:\Users\one\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\one\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\one\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
after_para.tail()
# Out:
#                                                       V1
# 33497  지5 핑크 ㅋㅌㄱㅂ 어제 오전 주문넣었 저녁 해피콜받 오늘배송받았네 ㅎㅎ 부산 서울...
# 33498  [g5 어제 네이버 지도 전화 어플 크 때 데이터통신 안 되 자꾸 진입 로딩 근데 ...
# 33499                           ㅎㄴㅁㄷ님 ㅅㅋs7기변좀 부탁 징징 잉이 요
# 33500                                     ㅅㅋㄱㅂ g5 뜨 기다 다
# 33501              g5 친구 끼리 추천 이벤트 저의 추천 코드 g5 cv74b 입 다

# %%
raw_text.to_csv('123.csv', index=False)
